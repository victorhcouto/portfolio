# %% [markdown]
# # Análise Exploratória de Dados iris.csv

# %%
import time
import numpy as np
import pandas as pd
import matplotlib as mat
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
# %matplotlib inline

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print(len(df))
df.head()
# Out:
# 150
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris.target_names

# %%
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
df.head()

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.groupby('target').mean().T

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.isnull().sum(axis=0)
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %% [markdown]
# # Visualização

# %%
exclude = ['Id', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'target']
df.loc[:, df.columns.difference(exclude)].hist() 
plt.figure(figsize=(15,10))
plt.show()

# %%
plt.figure(figsize=(12, 8), dpi=80)
plt.scatter(range(len(df)), df['petal width (cm)'], c=df['target'])
plt.xlabel('Número da Linha', fontsize=fontsize)
plt.ylabel('Sepal length (cm)', fontsize=fontsize)
plt.title('Gráfico de Dispersão dos Atributos, colorido por marcadores da classe alvo', fontsize=fontsize)
#plt.title('Scatter plot of features, colored by target labels', fontsize=fontsize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-53478402c248> in <module>
#       1 plt.figure(figsize=(12, 8), dpi=80)
#       2 plt.scatter(range(len(df)), df['petal width (cm)'], c=df['target'])
# ----> 3 plt.xlabel('Número da Linha', fontsize=fontsize)
#       4 plt.ylabel('Sepal length (cm)', fontsize=fontsize)
#       5 plt.title('Gráfico de Dispersão dos Atributos, colorido por marcadores da classe alvo', fontsize=fontsize)
#
# NameError: name 'fontsize' is not defined

# %%
plt.figure(figsize=(12, 8), dpi=80)
plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])
plt.xlabel('petal length (cm)', fontsize=fontsize)
plt.ylabel('petal width (cm)', fontsize=fontsize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2cf915a0e7f4> in <module>
#       1 plt.figure(figsize=(12, 8), dpi=80)
#       2 plt.scatter(df['petal length (cm)'], df['petal width (cm)'], c=df['target'])
# ----> 3 plt.xlabel('petal length (cm)', fontsize=fontsize)
#       4 plt.ylabel('petal width (cm)', fontsize=fontsize)
#
# NameError: name 'fontsize' is not defined

# %%
attributes = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
pd.plotting.scatter_matrix(df[attributes], figsize=(16, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbdb5f760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbdbba340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe2947c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe2bfc40>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe2ed130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe324490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe324580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe34fa60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe3b9310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe3e6760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe411bb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe43e0a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe476490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe4a28e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe4d2d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbe50a1c0>]],
#       dtype=object)

# %%
df.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbebead00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbec049d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbeeb5e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbeeed2e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fecbef1a730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fecbef46c10>]],
#       dtype=object)
